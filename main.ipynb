# %%
import json
from pathlib import Path
from datetime import datetime

# Criar estrutura de diretórios para repositório de dados
def criar_repositorio_dados(caminho_raiz: str = "./repositorio_dados") -> dict:
   """
   Cria estrutura padrão de repositório para engenharia de dados
   com qualidade e organização corporativa.
   """
   
   estrutura = {
      "raiz": caminho_raiz,
      "diretorios": {
         "raw": "Dados brutos, sem processamento",
         "processed": "Dados processados e validados",
         "staging": "Dados em transição para warehouse",
         "scripts": "Scripts Python para ETL/ELT",
         "notebooks": "Jupyter notebooks de análise",
         "config": "Arquivos de configuração",
         "logs": "Registros de execução",
         "tests": "Testes unitários e integração",
         "docs": "Documentação do projeto",
         "models": "Modelos e artefatos ML",
         "output": "Resultados e exports"
      }
   }
   
   # Criar diretórios
   for subdir in estrutura["diretorios"].keys():
      caminho = Path(caminho_raiz) / subdir
      caminho.mkdir(parents=True, exist_ok=True)
      
      # Criar .gitkeep para manter pastas vazias
      (caminho / ".gitkeep").touch()
   
   # Criar arquivo de metadados
   metadados = {
      "projeto": "Repositório de Dados Corporativo",
      "criado_em": datetime.now().isoformat(),
      "organizacao": "Petrobras",
      "versao": "1.0",
      "descricao": "Estrutura padrão para projetos de engenharia de dados"
   }
   
   with open(Path(caminho_raiz) / "metadata.json", "w") as f:
      json.dump(metadados, f, indent=2, ensure_ascii=False)
   
   # Criar .gitignore padrão
   gitignore_conteudo = """
# Dados sensíveis
raw/
*.csv
*.xlsx
*.parquet
*.db

# Ambientes
.env
.venv
venv/
__pycache__/
*.pyc

# IDEs
.vscode/
.idea/
*.swp

# Logs
logs/
*.log

# Outputs temporários
output/temp/
"""
   
   with open(Path(caminho_raiz) / ".gitignore", "w") as f:
      f.write(gitignore_conteudo)
   
   print(f"✓ Repositório criado em: {caminho_raiz}")
   print(f"\nEstrutura de diretórios:")
   for dir_nome, descricao in estrutura["diretorios"].items():
      print(f"  ├── {dir_nome:15} - {descricao}")
   
   return estrutura

# Executar criação
repositorio = criar_repositorio_dados("./repositorio_dados_petrobras")
# Out:
# ✓ Repositório criado em: ./repositorio_dados_petrobras
#
# Estrutura de diretórios:
#   ├── raw             - Dados brutos, sem processamento
#   ├── processed       - Dados processados e validados
#   ├── staging         - Dados em transição para warehouse
#   ├── scripts         - Scripts Python para ETL/ELT
#   ├── notebooks       - Jupyter notebooks de análise
#   ├── config          - Arquivos de configuração
#   ├── logs            - Registros de execução
#   ├── tests           - Testes unitários e integração
#   ├── docs            - Documentação do projeto
#   ├── models          - Modelos e artefatos ML
#   ├── output          - Resultados e exports

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# Gerar dados de exemplo para o repositório
np.random.seed(42)

# 1. Dados brutos - Produção de petróleo
datas = pd.date_range(start='2023-01-01', end='2024-01-01', freq='D')
producao_raw = pd.DataFrame({
   'data': datas,
   'plataforma': np.random.choice(['P-01', 'P-02', 'P-03', 'P-04'], len(datas)),
   'producao_barris': np.random.uniform(1000, 5000, len(datas)),
   'pressao_psi': np.random.uniform(2000, 3500, len(datas)),
   'temperatura_celsius': np.random.uniform(40, 80, len(datas)),
   'qualidade_api': np.random.uniform(25, 35, len(datas))
})

# Salvar em raw
producao_raw.to_csv('./repositorio_dados_petrobras/raw/producao_bruta.csv', index=False)

# 2. Dados processados - Agregação diária
producao_processada = producao_raw.groupby('data').agg({
   'producao_barris': 'mean',
   'pressao_psi': 'mean',
   'temperatura_celsius': 'mean',
   'qualidade_api': 'mean'
}).reset_index()

producao_processada.to_csv('./repositorio_dados_petrobras/processed/producao_diaria.csv', index=False)

# 3. Dados de staging - Agregação mensal
producao_processada['ano_mes'] = producao_processada['data'].dt.to_period('M')
producao_staging = producao_processada.groupby('ano_mes').agg({
   'producao_barris': 'sum',
   'pressao_psi': 'mean',
   'temperatura_celsius': 'mean',
   'qualidade_api': 'mean'
}).reset_index()

producao_staging.to_csv('./repositorio_dados_petrobras/staging/producao_mensal.csv', index=False)

print("✓ Dados gerados com sucesso!")
print(f"\n📊 Amostra dos dados brutos (primeiras 5 linhas):")
print(producao_raw.head())
print(f"\n📊 Amostra dos dados processados (primeiras 5 linhas):")
print(producao_processada.head())
print(f"\n📊 Dados de staging:")
print(producao_staging)
# Out:
# ✓ Dados gerados com sucesso!
#
# 📊 Amostra dos dados brutos (primeiras 5 linhas):
#         data plataforma  producao_barris  pressao_psi  temperatura_celsius  \
# 0 2023-01-01       P-03      4509.357414  3158.477588            57.445061
# 1 2023-01-02       P-04      2031.766511  2780.245252            51.778630
# 2 2023-01-03       P-01      3639.936184  3278.272250            77.938132
# 3 2023-01-04       P-03      4268.888801  2827.860258            70.544232
# 4 2023-01-05       P-03      3220.803246  2841.406957            45.604527
#
#    qualidade_api
# 0      32.024650
# 1      30.596487
# 2      25.097708
# 3      28.264613
# 4      30.177116
#
# 📊 Amostra dos dados processados (primeiras 5 linhas):
#         data  producao_barris  pressao_psi  temperatura_celsius  \
# 0 2023-01-01      4509.357414  3158.477588            57.445061
# 1 2023-01-02      2031.766511  2780.245252            51.778630
# 2 2023-01-03      3639.936184  3278.272250            77.938132
# 3 2023-01-04      4268.888801  2827.860258            70.544232
# 4 2023-01-05      3220.803246  2841.406957            45.604527
#
#    qualidade_api  ano_mes
# 0      32.024650  2023-01
# 1      30.596487  2023-01
# 2      25.097708  2023-01
# 3      28.264613  2023-01
# 4      30.177116  2023-01
#
# 📊 Dados de staging:
#     ano_mes  producao_barris  pressao_psi  temperatura_celsius  qualidade_api
# 0   2023-01     94563.917405  2779.935448            59.180086      29.469287
# 1   2023-02     87650.387214  2494.735749            59.581788      29.966779
# 2   2023-03    105937.337336  2697.523421            59.523421      30.692150
# 3   2023-04     85148.761133  2612.076993            62.246146      29.661831
# 4   2023-05     91981.455606  2708.211167            63.272750      29.916670
# 5   2023-06     84171.141542  2749.472310            58.582074      30.466288
# 6   2023-07     92917.981090  2821.270641            61.542712      30.219954
# 7   2023-08    100470.513547  2750.446793            62.980130      29.894733
# 8   2023-09     89735.511421  2859.852419            61.418632      30.022394
# 9   2023-10     94698.708113  2680.292722            59.768088      29.877657
# 10  2023-11     97977.557515  2607.872971            61.982757      29.327457
# 11  2023-12    105515.111467  2642.862725            56.905542      30.605274
# 12  2024-01      3081.230804  2828.070771            64.726229      26.277135
